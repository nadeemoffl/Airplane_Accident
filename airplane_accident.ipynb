# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import os
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
#from gensim import corpora, models
from collections import Counter
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.metrics import f1_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix

# %%
df1 = pd.read_csv("/Users/nadeemm/Downloads/Kaggle Data sets/HackerEarth/3c055e822d5b11ea/train.csv",delimiter=",")
df1.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
df1.dataframeName = 'sample_submission.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 10000 rows and 12 columns

# %%
df1.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
df2 = pd.read_csv("/Users/nadeemm/Downloads/Kaggle Data sets/HackerEarth/3c055e822d5b11ea/test.csv",delimiter=",")

# %%
df2.dataframeName = 'test.csv'
nRow,nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 2500 rows and 11 columns

# %%
df2.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     19.497717                     16                        6
# 1     58.173516                     15                        3
# 2     33.287671                     15                        3
# 3      3.287671                     21                        5
# 4     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  Adverse_Weather_Metric  \
# 0                   4   37949.724386           2                0.069692
# ...

# %%
df1.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
df1_copy = df1.copy()

# %%
df1_copy.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
df1_safety_score = df1_copy.sort_values(by = ['Safety_Score','Total_Safety_Complaints','Days_Since_Inspection','Violations','Accident_ID','Accident_Type_Code'],
    axis=0,
    ascending=True,
    inplace=False,
    kind='quicksort',
    na_position='last')

# %%
df1_safety_score.head()
# Out:
#                        Severity  Safety_Score  Days_Since_Inspection  \
# 8619  Highly_Fatal_And_Damaging           0.0                     20
# 1339  Highly_Fatal_And_Damaging           0.0                     20
# 4690  Highly_Fatal_And_Damaging           0.0                     20
# 9473  Highly_Fatal_And_Damaging           0.0                     20
# 4171  Highly_Fatal_And_Damaging           0.0                     21
#
#       Total_Safety_Complaints  Control_Metric  Turbulence_In_gforces  \
# 8619                        0       70.282589               0.199633
# 1339                        1       65.861440               0.368043
# 4690                        7       64.995442               0.549435
# 9473                        9       80.446673               0.396892
# 4171                       14       63.901550               0.322604
#
#       Cabin_Temperature  Accident_Type_Code  Max_Elevation  Violations  \
# ...

# %%
df_safety_score_decending = df1_copy.sort_values(by = ['Safety_Score','Total_Safety_Complaints','Days_Since_Inspection','Violations','Accident_ID','Accident_Type_Code'],
    axis=0,
    ascending=False,
    inplace=False,
    kind='quicksort',
    na_position='last')

# %%
df_safety_score_decending
# Out:
#                                      Severity  Safety_Score  \
# 1247        Significant_Damage_And_Fatalities    100.000000
# 9137        Significant_Damage_And_Fatalities    100.000000
# 4359        Significant_Damage_And_Fatalities    100.000000
# 7461  Significant_Damage_And_Serious_Injuries     98.401826
# 6464  Significant_Damage_And_Serious_Injuries     98.401826
# ...                                       ...           ...
# 4171                Highly_Fatal_And_Damaging      0.000000
# 9473                Highly_Fatal_And_Damaging      0.000000
# 4690                Highly_Fatal_And_Damaging      0.000000
# 1339                Highly_Fatal_And_Damaging      0.000000
# 8619                Highly_Fatal_And_Damaging      0.000000
#
#       Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 1247                      6                       17       72.971741
# 9137                      5                        3       81.358250
# ...

# %%
df1.columns
# Out:
# Index(['Severity', 'Safety_Score', 'Days_Since_Inspection',
#        'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
#        'Cabin_Temperature', 'Accident_Type_Code', 'Max_Elevation',
#        'Violations', 'Adverse_Weather_Metric', 'Accident_ID'],
#       dtype='object')

# %%
dfff = df1_copy.sort_values(by = ['Severity', 'Safety_Score', 'Days_Since_Inspection',
       'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
       'Cabin_Temperature', 'Accident_Type_Code', 'Max_Elevation',
       'Violations', 'Adverse_Weather_Metric', 'Accident_ID'],
    axis=0,
    ascending=True,
    inplace=False,
    kind='quicksort',
    na_position='last')

# %%
dfff
# Out:
#                                      Severity  Safety_Score  \
# 8619                Highly_Fatal_And_Damaging      0.000000
# 1339                Highly_Fatal_And_Damaging      0.000000
# 4690                Highly_Fatal_And_Damaging      0.000000
# 9473                Highly_Fatal_And_Damaging      0.000000
# 4171                Highly_Fatal_And_Damaging      0.000000
# ...                                       ...           ...
# 6464  Significant_Damage_And_Serious_Injuries     98.401826
# 1886  Significant_Damage_And_Serious_Injuries     98.401826
# 7461  Significant_Damage_And_Serious_Injuries     98.401826
# 5112  Significant_Damage_And_Serious_Injuries     98.401826
# 7150  Significant_Damage_And_Serious_Injuries     98.401826
#
#       Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 8619                     20                        0       70.282589
# 1339                     20                        1       65.861440
# ...

# %%
dfff.drop(['Adverse_Weather_Metric','Violations','Max_Elevation','Accident_Type_Code','Cabin_Temperature','Turbulence_In_gforces','Control_Metric','Total_Safety_Complaints'],axis=1,inplace=True)

# %%
dfff
# Out:
#                                      Severity  Safety_Score  \
# 8619                Highly_Fatal_And_Damaging      0.000000
# 1339                Highly_Fatal_And_Damaging      0.000000
# 4690                Highly_Fatal_And_Damaging      0.000000
# 9473                Highly_Fatal_And_Damaging      0.000000
# 4171                Highly_Fatal_And_Damaging      0.000000
# ...                                       ...           ...
# 6464  Significant_Damage_And_Serious_Injuries     98.401826
# 1886  Significant_Damage_And_Serious_Injuries     98.401826
# 7461  Significant_Damage_And_Serious_Injuries     98.401826
# 5112  Significant_Damage_And_Serious_Injuries     98.401826
# 7150  Significant_Damage_And_Serious_Injuries     98.401826
#
#       Days_Since_Inspection  Accident_ID
# 8619                     20        12099
# 1339                     20         7970
# 4690                     20        10859
# 9473                     20        11142
# ...

# %%
df2.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     19.497717                     16                        6
# 1     58.173516                     15                        3
# 2     33.287671                     15                        3
# 3      3.287671                     21                        5
# 4     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  Adverse_Weather_Metric  \
# 0                   4   37949.724386           2                0.069692
# ...

# %%
df22 = df2.copy()

# %%
df22.drop(['Adverse_Weather_Metric','Violations','Max_Elevation','Accident_Type_Code','Cabin_Temperature','Turbulence_In_gforces','Control_Metric','Total_Safety_Complaints'],axis=1, inplace=True)

# %%
df22.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Accident_ID
# 0     19.497717                     16            1
# 1     58.173516                     15           10
# 2     33.287671                     15           14
# 3      3.287671                     21           17
# 4     10.867580                     18           21

# %%
dfff.head()
# Out:
#                        Severity  Safety_Score  Days_Since_Inspection  \
# 8619  Highly_Fatal_And_Damaging           0.0                     20
# 1339  Highly_Fatal_And_Damaging           0.0                     20
# 4690  Highly_Fatal_And_Damaging           0.0                     20
# 9473  Highly_Fatal_And_Damaging           0.0                     20
# 4171  Highly_Fatal_And_Damaging           0.0                     21
#
#       Accident_ID
# 8619        12099
# 1339         7970
# 4690        10859
# 9473        11142
# 4171        12038

# %%
  dfff['Severity']
# Out:
# 8619                  Highly_Fatal_And_Damaging
# 1339                  Highly_Fatal_And_Damaging
# 4690                  Highly_Fatal_And_Damaging
# 9473                  Highly_Fatal_And_Damaging
# 4171                  Highly_Fatal_And_Damaging
#                          ...
# 6464    Significant_Damage_And_Serious_Injuries
# 1886    Significant_Damage_And_Serious_Injuries
# 7461    Significant_Damage_And_Serious_Injuries
# 5112    Significant_Damage_And_Serious_Injuries
# 7150    Significant_Damage_And_Serious_Injuries
# Name: Severity, Length: 10000, dtype: object

# %%
dff1 = dfff["Severity"].astype('category')

# %%
dff1.dtype
# Out:
# CategoricalDtype(categories=['Highly_Fatal_And_Damaging', 'Minor_Damage_And_Injuries',
#                   'Significant_Damage_And_Fatalities',
#                   'Significant_Damage_And_Serious_Injuries'],
#                  ordered=False)

# %%
dfff['Severity'] = dfff['Severity']

# %%
dfff.cc = pd.Categorical(dfff.Severity)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
dfff["Severity"]
# Out:
# 8619                  Highly_Fatal_And_Damaging
# 1339                  Highly_Fatal_And_Damaging
# 4690                  Highly_Fatal_And_Damaging
# 9473                  Highly_Fatal_And_Damaging
# 4171                  Highly_Fatal_And_Damaging
#                          ...
# 6464    Significant_Damage_And_Serious_Injuries
# 1886    Significant_Damage_And_Serious_Injuries
# 7461    Significant_Damage_And_Serious_Injuries
# 5112    Significant_Damage_And_Serious_Injuries
# 7150    Significant_Damage_And_Serious_Injuries
# Name: Severity, Length: 10000, dtype: object

# %%
train_data["Severity"] = train_data["Severity"].astype('category')

# %%
dfff.dtypes
# Out:
# Severity                  object
# Safety_Score             float64
# Days_Since_Inspection      int64
# Accident_ID                int64
# dtype: object

# %%
train_data = dfff.copy()

# %%
train_data
# Out:
#                                      Severity  Safety_Score  \
# 8619                Highly_Fatal_And_Damaging      0.000000
# 1339                Highly_Fatal_And_Damaging      0.000000
# 4690                Highly_Fatal_And_Damaging      0.000000
# 9473                Highly_Fatal_And_Damaging      0.000000
# 4171                Highly_Fatal_And_Damaging      0.000000
# ...                                       ...           ...
# 6464  Significant_Damage_And_Serious_Injuries     98.401826
# 1886  Significant_Damage_And_Serious_Injuries     98.401826
# 7461  Significant_Damage_And_Serious_Injuries     98.401826
# 5112  Significant_Damage_And_Serious_Injuries     98.401826
# 7150  Significant_Damage_And_Serious_Injuries     98.401826
#
#       Days_Since_Inspection  Accident_ID
# 8619                     20        12099
# 1339                     20         7970
# 4690                     20        10859
# 9473                     20        11142
# ...

# %%
train_data.isnull().sum()
# Out:
# Severity                 0
# Safety_Score             0
# Days_Since_Inspection    0
# Accident_ID              0
# dtype: int64

# %%
y = train_data['Severity']
x = train_data.drop(['Severity'],axis = 1)

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 1234)

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])


categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_attr),
        ('cat', categorical_transformer, cat_attr)])

# %%
clf_logreg = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression())])

# %%
score_1 = 100*(f1_score(y_true = y_train, y_pred = train_pred, average = 'weighted'))
print("F1_score :",score_1)

# %%
from xgboost import XGBClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-314-477fa34615c5> in <module>
# ----> 1 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
pip install xgboost
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/96/84/4e2cae6247f397f83d8adc5c2a2a0c5d7d790a14a4c7400ff6574586f589/xgboost-0.90.tar.gz
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/gp/q0kq47m13_j3_3zxbc5h94f00000gn/T/pip-install-kbttazjm/xgboost/setup.py'"'"'; __file__='"'"'/private/var/folders/gp/q0kq47m13_j3_3zxbc5h94f00000gn/T/pip-install-kbttazjm/xgboost/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base pip-egg-info
#          cwd: /private/var/folders/gp/q0kq47m13_j3_3zxbc5h94f00000gn/T/pip-install-kbttazjm/xgboost/
#     Complete output (29 lines):
#     ++ pwd
#     + oldpath=/private/var/folders/gp/q0kq47m13_j3_3zxbc5h94f00000gn/T/pip-install-kbttazjm/xgboost
#     + cd ./xgboost/
# ...

# %%
from datetime import datetime
from sklearn import metrics
from sklearn.metrics import classification_report     
from sklearn.metrics import confusion_matrix     
from sklearn.preprocessing import StandardScaler  # Helps us in Standardizing the data
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier

from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score,recall_score,precision_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-313-8e6b1ec3b582> in <module>
#       9 from sklearn.tree import DecisionTreeClassifier
#      10 from sklearn.ensemble import VotingClassifier
# ---> 11 from xgboost import XGBClassifier
#      12 from sklearn.ensemble import BaggingClassifier
#      13 from sklearn.svm import SVC
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
log_reg = LogisticRegression(random_state= 42)
svc = SVC(random_state= 42,gamma='auto',probability=True)
rf = RandomForestClassifier(random_state= 42,n_estimators = 100)
ada = AdaBoostClassifier(random_state= 42)
dt=DecisionTreeClassifier(criterion = "gini",random_state = 42)
bc = BaggingClassifier(base_estimator=dt, random_state=42)
vc = VotingClassifier(estimators=[('LogisticRegresion', log_reg), ('RandomForest',rf), ('SupportVectorMachine', svc),('AdaBoost',ada),('DecisionTree',dt)],voting='soft')

# %%
# Predict function
def training_predict(trainer, X_train, Y_train, X_test, Y_test):
    scores = {} # Initializing a Dictionary to store evaluation metrics    
    trainer.fit(X_train, Y_train)  # Training
    Y_pred = trainer.predict(X_test) # Predicts  
    scores['Accuracy_test'] = accuracy_score(Y_test , Y_pred)    
    scores['Recall_test'] = recall_score(Y_test , Y_pred,average='macro')    
    scores['Precision_test'] = precision_score(Y_test , Y_pred,average='macro')    
    return scores

# %%
# Ignore the error
import time
start = time.time()
predictors = {} # Initializing a dictionary to store training and testing data
for model in [log_reg, svc, rf,dt,ada,bc,vc]: # these are our objects that we instantiated above. We loop through them
    model_name = model.__class__.__name__
    predictors[model_name]  = {}
    predictors[model_name] =  training_predict(model, X_train, y_train, X_test, y_test)#Scores that is returned from trainer goes to
                                                                             # the respective predictor   print('Loop Ended at {}'.format(datetime.now().strftime("%H:%M:%S")))
print('\n')    
print('Loop took {} mins'.format((time.time() - start) / 60))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
pd.DataFrame(predictors).T
# Out:
#                         Accuracy_test  Recall_test  Precision_test
# LogisticRegression           0.360000     0.320564        0.257503
# SVC                          0.329667     0.269161        0.436145
# RandomForestClassifier       0.747333     0.736691        0.740657
# DecisionTreeClassifier       0.732000     0.723570        0.724610
# AdaBoostClassifier           0.548333     0.505457        0.468605
# BaggingClassifier            0.736667     0.723699        0.732292
# VotingClassifier             0.737000     0.727303        0.730485

# %%
rf1=RandomForestClassifier(n_estimators=10)

# %%
rf1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=rf1.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score

# %%
y_train_pred=rf1.predict(X_train)
print("F1_Score for Train:",f1_score(y_train,y_train_pred,average='macro'))
# Out:
# F1_Score for Train: 0.9780587973655467

# %%
print("Accuracy :",accuracy_score(y_test,y_pred))
# Out:
# Accuracy : 0.7273333333333334

# %%
sub=rf1.predict(df22)

# %%
final= pd.DataFrame({'Accident_ID' : df22['Accident_ID'],
                     'Severity' : sub})

# %%
final.to_csv("submission_copy.csv",index=False)
final.shape
# Out:
# (2500, 2)
